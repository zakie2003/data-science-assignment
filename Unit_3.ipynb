# %% [markdown]
# **Q3.1)Program to creat a Bar Plot with Overlay.**

# %%
import seaborn as sb
import pandas as pd

# %%
file=pd.read_csv("./Datasets/marks.csv")
print(file)
# Out:
#   Subject  Boys  Girls
# 0    java    43     35
# 1   react    86     72
# 2  python    89     80
# 3      OS    67     54

# %%
chart=sb.barplot(x=file["Subject"],y=file["Boys"],color="red")
chart=sb.barplot(x=file["Subject"],y=file["Girls"],color="green")
chart.set(xlabel="Subjects",ylabel="Scores")
# Out:
# [Text(0.5, 0, 'Subjects'), Text(0, 0.5, 'Scores')]

# %% [markdown]
# **Q3.2)Program to create a contegency table.**

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
f=pd.read_csv("./Datasets/toy_data.csv")

# %%
inp=f[["Air temperature [K]","Process temperature [K]","Rotational speed [rpm]","Torque [Nm]","Tool wear [min]"]]
minmax=MinMaxScaler()
f[["Air temperature [K]","Process temperature [K]","Rotational speed [rpm]","Torque [Nm]","Tool wear [min]"]]=minmax.fit_transform(f[["Air temperature [K]","Process temperature [K]","Rotational speed [rpm]","Torque [Nm]","Tool wear [min]"]])

# %%
sb.heatmap(inp.corr(), cmap="YlGnBu", annot=True)
# Out:
# <Axes: >
